# %% [markdown]
# # Data exploration and preparation for Machine Learning

# %% [markdown]
# ## Hands on case study
# Explore NYC Trips dataset to
# - get knowledge of relationships between variables
#   - create better features
# - remove outliers
#   - get a robuster model
#
# using
#   - python in jupyter
#   - pandas, matplotlib and seaborn modules

# %% [markdown]
# ### Useful shortcuts in Jupyter
#   - run current cell
#     - `shift + Enter`
#   - go into cell to modify
#     - `Enter` (the frame around cell becomes **green**)
#   - deselect cell
#     - `Esc` (the frame around cell becomes **blue**)
#   - new cell **above** current cell
#     - `Esc` to deselect followed by `A`
#   - new cell **below** current cell
#     - `Esc` to deselect followed by `B`

# %% [markdown]
# ## Introduce dataset - New York City Taxi Trip Duration
# - challenge on kaggle
# - goal to predict the `trip_duration` based on few features:
#   - `vendor_id` (provider of the trip, such as Uber, Lyft, etc.)
#   - `pickup_datetime`
#   - `passenger_count`
#   - `pickup_longitude`
#   - `pickup_latitude`
#   - `dropoff_longitude`
#   - `dropoff_latitude`

# %% [markdown]
# ## Let's get started
# ### Downloading the dataset
# - create an account at https://www.kaggle.com/
# - go to https://www.kaggle.com/hobilek/nyc-trips-amld and fork it
# - you can also just download the dataset and work locally on your jupyter

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator, FormatStrFormatter
import seaborn as sns

# %%
# increase the font size of the plots
FONT_SIZE = 14
mpl.rcParams['xtick.labelsize'] = FONT_SIZE 
mpl.rcParams['ytick.labelsize'] = FONT_SIZE
mpl.rcParams['legend.fontsize'] = FONT_SIZE
mpl.rcParams['axes.labelsize'] = FONT_SIZE
mpl.rcParams['figure.figsize'] = (10, 10)

# %%
def precision(x, precision):
    """Round a number or array to a given precision
    :Example:

    precision(np.array([3.71, 4.59]), 0.02)
    >> array([3.72, 4.6 ])
    
    precision(np.array([154, 396]), 10)
    >> array([150, 400 ])
    """
    return (np.round(x / precision) * precision).astype(type(precision))

def load_dataset(file_path):
    df = pd.read_csv(file_path, index_col='id', parse_dates=['pickup_datetime'])
    df = df.head(100000)
    # convert the `trip_duration` from seconds to minutes for convenience
    df['trip_duration_minutes'] = df['trip_duration'] / 60.0
    df.drop(['dropoff_datetime', 'store_and_fwd_flag', 'trip_duration'], axis=1, inplace=True)
    return df

def plot_boxplot(df, n_rows, n_cols, figsize=(18, 24)):
    numeric_columns = df.select_dtypes(include=np.number).columns
    fig, axn = plt.subplots(n_rows, n_cols, figsize=figsize)
    for col, ax in zip(numeric_columns, axn.flatten()):
        sns.boxplot(df[col], orient='v', ax=ax)

# %%
file_path = '~/Downloads/train.csv'

df = load_dataset(file_path)

df.head()
# Out:
#            vendor_id     pickup_datetime  passenger_count  pickup_longitude  \
# id
# id2875421          2 2016-03-14 17:24:55                1        -73.982155
# id2377394          1 2016-06-12 00:43:35                1        -73.980415
# id3858529          2 2016-01-19 11:35:24                1        -73.979027
# id3504673          2 2016-04-06 19:32:31                1        -74.010040
# id2181028          2 2016-03-26 13:30:55                1        -73.973053
#
#            pickup_latitude  dropoff_longitude  dropoff_latitude  \
# id
# id2875421        40.767937         -73.964630         40.765602
# id2377394        40.738564         -73.999481         40.731152
# id3858529        40.763939         -74.005333         40.710087
# id3504673        40.719971         -74.012268         40.706718
# id2181028        40.793209         -73.972923         40.782520
#
#            trip_duration_minutes
# id
# id2875421               7.583333
# id2377394              11.050000
# id3858529              35.400000
# id3504673               7.150000
# id2181028               7.250000

# %% [markdown]
# ## TASK 1 - Exploring column values
# How are the values in each column distributed?
# - Which columns include missing values?
# - Which columns include only few different values?
# - Did you find any outliers? Filter them out.
# - *(optional)* Based on your information, try to sketch the distribution.

# %% [markdown]
# The function `describe` shows minimum and maximum of each column, as well as mean, quantiles and other statistics.
#
# It is similar to R's `summary` function.

# %%
df.describe(percentiles=[0.1, 0.25, 0.75, 0.9])
# Out:
#           vendor_id  passenger_count  pickup_longitude  pickup_latitude  \
# count  100000.00000    100000.000000     100000.000000    100000.000000
# mean        1.53349         1.667810        -73.973464        40.751059
# std         0.49888         1.317603          0.038294         0.028152
# min         1.00000         0.000000        -74.533875        40.433842
# 10%         1.00000         1.000000        -74.002587        40.720359
# 25%         1.00000         1.000000        -73.991852        40.737370
# 50%         2.00000         1.000000        -73.981712        40.754269
# 75%         2.00000         2.000000        -73.967209        40.768426
# 90%         2.00000         4.000000        -73.951881        40.780434
# max         2.00000         6.000000        -73.334023        41.319164
#
#        dropoff_longitude  dropoff_latitude  trip_duration_minutes
# count      100000.000000     100000.000000          100000.000000
# mean          -73.973455         40.751947              15.664404
# std             0.036625          0.032452              50.075687
# min           -74.562355         40.441662               0.016667
# 10%           -74.002923         40.715488               4.066667
# 25%           -73.991394         40.735844               6.600000
# 50%           -73.979782         40.754478              11.033333
# 75%           -73.962919         40.769928              17.933333
# 90%           -73.947083         40.785030              27.216667
# max           -72.711395         41.311520            1439.833333

# %% [markdown]
# We could also visualize the previous summary using boxplots.

# %%
plot_boxplot(df, n_rows=4, n_cols=2)

# %% [markdown]
# ## TASK 2 - Outliers (part 1)
# - Eliminate outliers from the column `trip_duration`.

# %%
fig = plt.figure()
ax = fig.gca()
ax.hist(df['trip_duration_minutes'], bins=50)
ax.set_xlabel('trip duration in min')
ax.set_ylabel('number of trips')
ax.grid()

# %% [markdown]
# Vast majority in the first bin. This means there are few tours with a very high trip duration. What now?
#
# **Log transform on y-axis.**

# %%
fig = plt.figure()
ax = fig.gca()
ax.hist(df['trip_duration_minutes'], bins=50)
ax.set_xlabel('trip duration in min')
ax.set_ylabel('number of trips')
ax.set_yscale('log')
ax.grid()

# %%
df = df[df['trip_duration_minutes'] < 200]

# %% [markdown]
# Continue exploring the distribution of `trip_duration` further and keep filtering out values until you are happy with the result.
#
# - Which values did you filter out and why?
#   - Don't forget to look not only at big values but also very small values.
# - Show the distribution after filtering outliers.

# %%
fig = plt.figure()
ax = fig.gca()
ax.hist(df['trip_duration_minutes'], bins=50)
ax.set_xlabel('trip duration in min')
ax.set_ylabel('number of trips')
ax.set_yscale('log')
ax.grid()

# %%
short_trip_duration = df.loc[df['trip_duration_minutes'] < 10, 'trip_duration_minutes']
fig = plt.figure(figsize=(5,5))
ax = fig.gca()
ax.hist(short_trip_duration, bins=50)
ax.set_xlabel('trip duration in min')
ax.set_ylabel('number of trips')
ax.set_yscale('log')
ax.grid()

# %%
df = df[df['trip_duration_minutes'].between(1, 100)]

# %% [markdown]
# ## TASK 3 - Outliers (part 2)
# Filter out outliers in location columns
# - `pickup_longitude`
# - `pickup_latitude`
# - `dropoff_longitude`
# - `dropoff_latitude`
#
# Visualize the pickup and dropoff locations in a scatter plot.

# %%
fig = plt.figure(figsize=(16, 12))
ax = fig.gca()
s = ax.scatter(df['pickup_longitude'], df['pickup_latitude'], marker='.', s=1, 
               c=df['trip_duration_minutes'], cmap='RdYlGn_r')
ax.set_title('pickup locations', fontsize=20)
ax.set_xlabel('longitude')
ax.set_ylabel('latitude')
ax.xaxis.set_major_locator(MultipleLocator(0.2))
ax.yaxis.set_major_locator(MultipleLocator(0.2))
ax.grid()
fig.colorbar(s);

# %%
df = df[df['pickup_latitude'].between(40.55, 40.95) & \
        df['pickup_longitude'].between(-74.1, -73.7)]

# %% [markdown]
# Is filtering on these values sufficient?
#
# Once you cleaned the dataset based on pickup location, do the same for dropoff location.

# %%
df = df[df['pickup_latitude'].between(40.6,40.9) & \
        df['dropoff_latitude'].between(40.6,40.9) & \
        df['pickup_longitude'].between(-74.05,-73.76) & \
        df['dropoff_longitude'].between(-74.05,-73.76)]

# %%
fig = plt.figure(figsize=(16, 12))
ax = fig.gca()
s = ax.scatter(df['pickup_longitude'], df['pickup_latitude'], marker='.', s=1, 
               c=df['trip_duration_minutes'], cmap='RdYlGn_r')
ax.set_title('pickup locations', fontsize=20)
ax.set_xlabel('longitude')
ax.set_ylabel('latitude')
ax.xaxis.set_major_locator(MultipleLocator(0.05))
ax.yaxis.set_major_locator(MultipleLocator(0.05))
ax.grid()
fig.colorbar(s);

# %%
fig = plt.figure(figsize=(16, 12))
ax = fig.gca()
s = ax.scatter(df['dropoff_longitude'], df['dropoff_latitude'], marker='.', s=1, 
               c=df['trip_duration_minutes'], cmap='RdYlGn_r')
ax.set_title('dropoff locations', fontsize=20)
ax.set_xlabel('longitude')
ax.set_ylabel('latitude')
ax.xaxis.set_major_locator(MultipleLocator(0.05))
ax.yaxis.set_major_locator(MultipleLocator(0.05))
ax.grid()
fig.colorbar(s);

# %% [markdown]
# ## TASK 4 - locations with long trips
# At which pickup / dropoff locations can we find the longest trips? Does it make sense?

# %%
fig = plt.figure(figsize=(16, 12))
ax = fig.gca()
df.plot.hexbin(x='pickup_longitude', y='pickup_latitude', 
               C='trip_duration_minutes', gridsize=20, cmap='Blues', ax=ax);

# %%
pickup = df.groupby([precision(df['pickup_longitude'], 0.02), 
                     precision(df['pickup_latitude'], 0.02)]
                   )['trip_duration_minutes'].mean().reset_index().round(2)
pick = pickup.pivot('pickup_latitude','pickup_longitude','trip_duration_minutes')
fig = plt.figure(figsize=(16, 12))
ax = fig.gca()
sns.heatmap(pick, cmap='Greens', ax=ax, annot=True, fmt=".0f")
ax.set_title('mean trip duration [minutes]', fontsize=20)
ax.invert_yaxis()

# %%
pickup = df.groupby([precision(df['pickup_longitude'], 0.02), 
                     precision(df['pickup_latitude'], 0.02)]
                   )['trip_duration_minutes'].count().reset_index().round(2)
pick = pickup.pivot('pickup_latitude','pickup_longitude','trip_duration_minutes')
fig = plt.figure(figsize=(16, 12))
ax = fig.gca()
sns.heatmap(pick, cmap='Greens', ax=ax, annot=True, fmt=".0f")
ax.set_title('Number of trips', fontsize=20)
ax.invert_yaxis()

# %% [markdown]
# Let's compute the mean `trip_duration_minutes` and number of trips at each `pickup_latitude` and `pickup_longitude`

# %%
pickup = df.groupby([precision(df['pickup_longitude'], 0.02), 
                     precision(df['pickup_latitude'], 0.02)]
                   )['trip_duration_minutes'].agg(['mean','size']).reset_index().round(2)

# %%
pickup.head()
# Out:
#    pickup_longitude  pickup_latitude   mean  size
# 0            -74.04            40.72   4.76     3
# 1            -74.04            40.74   4.83     1
# 2            -74.02            40.62   8.70     1
# 3            -74.02            40.64   8.83     7
# 4            -74.02            40.68  12.74     6

# %%
pick = pickup.pivot('pickup_latitude','pickup_longitude','mean')
fig = plt.figure(figsize=(16, 12))
ax = fig.gca()
sns.heatmap(pick, cmap='Greens', ax=ax, annot=True, fmt=".0f")
ax.set_title('mean trip duration [minutes]', fontsize=20)
ax.invert_yaxis()

# %% [markdown]
# **The longest trips are at N40.64 W73.9 with average 60 min trip duration and around N40.65 W73.8 with about 40 minutes.**

# %%
pick = pickup.pivot('pickup_latitude','pickup_longitude','size')
fig = plt.figure(figsize=(16, 12))
ax = fig.gca()
sns.heatmap(pick, cmap='Greens', ax=ax, annot=True, fmt=".0f")
ax.set_title('mean trip duration [minutes]', fontsize=20)
ax.invert_yaxis()

# %% [markdown]
# The N40.64 W73.9 point with average 60 min trip duration had only two trips so it is rather a outlier.
#
# The long trips around N40.65 W73.8 are actually valid is it is where the JFK Airport is located.

# %% [markdown]
# **Let's filter out all places with less than 10 trips.**

# %%
pickup = pickup[pickup['size'] >= 10]

# %%
pick = pickup.pivot('pickup_latitude','pickup_longitude','mean')
fig = plt.figure(figsize=(16, 12))
ax = fig.gca()
sns.heatmap(pick, cmap='Greens', ax=ax, annot=True, fmt=".0f")
ax.set_title('mean trip duration [minutes]', fontsize=20)
ax.invert_yaxis()

# %% [markdown]
# ## TASK 5 - Trip length vs time
# - When during the week do the customers make the shortest trips?
# - When do they make the longest trips?

# %%
df['weekday'] = df['pickup_datetime'].dt.weekday # 0 is Monday
df['hour'] = df['pickup_datetime'].dt.hour

# %% [markdown]
# Convert each week and hour into a number 0-167 representing number of hours since Monday midnight.

# %%
df['week_hours'] = df['weekday'] * 24 + df['hour']
week_hours = df.groupby('week_hours')['trip_duration_minutes'].mean()
fig = plt.figure(figsize=(20,6))
ax = fig.gca()
ax.plot(week_hours)
ax.set_xlabel('hours since Monday midnight', fontsize=18)
ax.set_ylabel('mean trip duration [minutes]', fontsize=18)
ax.xaxis.set_major_locator(MultipleLocator(24))
ax.xaxis.set_minor_locator(MultipleLocator(6))
ax.grid(which='minor', linestyle=':', linewidth=0.5)
ax.grid(which='major', linestyle='-', linewidth=1)

# %% [markdown]
# We can visualize the same thing as a table with `weekdays` \* `hours` and the value (color) in the cell represents the measure - in our case the *mean trip duration*.
#
# Use `sns.heatmap()` from the previous task to show this visualization.

# %%
trip_duration_per_weekday_hour = df.groupby(['weekday', 'hour']
                                           )['trip_duration_minutes'].mean().reset_index()
trip_duration_pivot = trip_duration_per_weekday_hour.pivot('weekday','hour','trip_duration_minutes')
fig = plt.figure(figsize=(20, 6))
ax = fig.gca()
sns.heatmap(trip_duration_pivot, cmap='Greens', ax=ax, annot=True, fmt=".1f")
ax.set_title('mean trip duration [minutes]', fontsize=20)
ax.set_xlabel('hour', fontsize=20)
ax.set_ylabel('', fontsize=20)
WEEKDAYS = ['Mo', 'Tu', 'We', 'Th', 'Fr', 'Sa', 'Su']
ax.set_yticklabels(WEEKDAYS, rotation='horizontal');

# %% [markdown]
# ## TASK 6 - Passenger count per vendor
# How does the distribution of `passenger_count` per vendor look like? Are they similar?
#
# Draw a bar chart to explore that.

# %%
# create a figure with two subplots - we will use for each vendor one
fig, axn = plt.subplots(1,2, figsize=(20, 7), sharey=True, sharex=True) # sharey enforces same scale on the y axis
# cycles through both vendor values 1 and 2 and the two axes we are going to plot at
max_val = 0
for vendor, ax in zip([1, 2], axn.flatten()):
    # number of trips per passenger_count for the given vendor
    v = df[df['vendor_id'] == vendor].groupby(['passenger_count']).size()
    # normalize the trip counts
    v = v / v.sum()
    # bar plot with color C0 (blue) or C1 (orange)
    ax.bar(v.index, v.values, color=f'C{vendor - 1}')
    ax.set_xlabel('passenger count')
    ax.set_ylabel('proportion of rides')
    ax.set_title(f'passenger count distribution for vendor {vendor}')
    ax.grid(linestyle=':')

# %% [markdown]
# Vendor 2 seems to have bigger cars as 15 % of the rides transport 5 or more passengers whereas for vendor 1 it is close to 0 %.
